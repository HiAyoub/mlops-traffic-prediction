# %% [markdown]
# # Preprocessing Demonstration
# This notebook demonstrates the functionalities of the `Preprocessing` class on the dataset `data/raw/dataset_debit_fcd.csv`.

# %%
pip install  pandas
# Out:
#   Cell In[35], line 1
#     pip install  pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 6.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/8.1 MB 4.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 3.9 MB/s eta 0:00:01
# ...

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.1 MB 7.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.1 MB 5.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.1 MB 4.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.1 MB 3.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.1 MB 3.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.1 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.1 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 7.1/11.1 MB 3.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 3.7 MB/s eta 0:00:01
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run notebook_init.py
from src.data_preprocessing.preprocess import Preprocessing
import pandas as pd

# %%
# Initialize the Preprocessing class with the dataset
file_path = '../data/raw/dataset_debit_fcd.csv'
print(Preprocessing)
preprocessor = Preprocessing(file_path)
# Out:
# 2025-05-12 16:07:45,699 - INFO - Initialisation de la classe Preprocessing.
# <class 'src.data_preprocessing.preprocess.Preprocessing'>
# 2025-05-12 16:07:46,390 - INFO - Dataset chargÃ© avec succÃ¨s depuis ../data/raw/dataset_debit_fcd.csv. Dimensions: (236550, 33)

# %%
preprocessor.drop_colonne(nom_col='Unnamed: 0')
# Out:
# 2025-05-12 16:08:29,924 - INFO - Tentative de suppression des colonnes: Unnamed: 0
# 2025-05-12 16:08:29,966 - INFO - Colonnes supprimÃ©es avec succÃ¨s: ['Unnamed: 0']
# Colonnes supprimÃ©es: ['Unnamed: 0']

# %%
# Verify the dataset after dropping the column
print(preprocessor.df.head())
# Out:
#    Id  AvgTt  MedTt  ratio  AvgSp  HvgSp  MedSp  SdSp   Hits  P5sp  ...  \
# 0   1   2.86   2.69   1.00   28.0   25.1   26.7   8.7  306.0  15.0  ...
# 1   1   2.78   2.64   0.97   27.7   25.8   27.2   7.2  738.0  18.0  ...
# 2   1   2.72   2.58   0.95   28.1   26.4   27.8   6.6  835.0  18.0  ...
# 3   1   2.73   2.59   0.95   28.1   26.3   27.7   6.7  811.0  18.0  ...
# 4   1   2.81   2.65   0.98   27.6   25.6   27.1   6.9  848.0  18.0  ...
#
#    P70sp  P75sp  P80sp  P85sp  P90sp  P95sp  heure  capteur  zone  debit
# 0   32.0   33.0   34.0   37.0   39.0   43.0      1      NaN   NaN    NaN
# 1   31.0   32.0   33.0   34.0   36.0   38.0     11      NaN   NaN    NaN
# 2   31.0   32.0   33.0   34.0   36.0   40.0     12      NaN   NaN    NaN
# 3   31.0   32.0   33.0   35.0   37.0   39.0     13      NaN   NaN    NaN
# 4   31.0   32.0   33.0   34.0   36.0   39.0     14      NaN   NaN    NaN
#
# [5 rows x 32 columns]

# %%
# Display dataset statistics
preprocessor.show_stats()
# Out:
# 2025-05-12 16:08:44,756 - INFO - Affichage des statistiques du DataFrame.
# 2025-05-12 16:08:44,765 - INFO - Dimensions du dataset: 236550 lignes et 32 colonnes
# 2025-05-12 16:08:44,767 - INFO - Types de données par colonne affichés.
# 2025-05-12 16:08:44,826 - INFO - Valeurs manquantes par colonne affichées.
# Dimensions du dataset: 236550 lignes et 32 colonnes
#
# Types de données par colonne :
# Id           int64
# AvgTt      float64
# MedTt      float64
# ratio      float64
# AvgSp      float64
# HvgSp      float64
# MedSp      float64
# SdSp       float64
# Hits       float64
# P5sp       float64
# P10sp      float64
# P15sp      float64
# P20sp      float64
# P25sp      float64
# P30sp      float64
# P35sp      float64
# P40sp      float64
# P45sp      float64
# P50sp      float64
# P55sp      float64
# P60sp      float64
# P65sp      float64
# P70sp      float64
# P75sp      float64
# P80sp      float64
# P85sp      float64
# P90sp      float64
# P95sp      float64
# ...

# %%
# Drop columns with all missing values
preprocessor.drop_columns_with_all_missing()
# Out:
# 2025-05-12 16:08:50,291 - INFO - Suppression des colonnes avec 100% de valeurs manquantes.
# 2025-05-12 16:08:50,344 - INFO - Colonnes supprimées avec succès.
# Colonnes avec 100% de valeurs manquantes supprimées.

# %%
# Identify and display outliers
outliers_dict, outlier_percentages = preprocessor.find_outliers()
print('Outliers:', outliers_dict)
print('Outlier Percentages:', outlier_percentages)
# Out:
# 2025-05-12 16:09:01,448 - INFO - Recherche des outliers dans les colonnes numériques.
# 2025-05-12 16:09:01,808 - INFO - Outliers détectés dans les colonnes: ['Id', 'AvgTt', 'MedTt', 'ratio', 'AvgSp', 'HvgSp', 'MedSp', 'SdSp', 'Hits', 'P5sp', 'P10sp', 'P15sp', 'P20sp', 'P25sp', 'P30sp', 'P35sp', 'P40sp', 'P45sp', 'P50sp', 'P55sp', 'P60sp', 'P65sp', 'P70sp', 'P75sp', 'P80sp', 'P85sp', 'P90sp', 'P95sp', 'heure', 'zone', 'debit']
# ...

# %%
# Split the dataset into X and Y
dfs_with_y = preprocessor.split_X_Y()
print('Number of splits:', len(dfs_with_y))
# Out:
# 2025-05-12 16:09:13,629 - INFO - Division des données en X et Y.
# Number of splits: 1

# %%
df = dfs_with_y[0] 
engen

# %%
# Process X to handle outliers
preprocessor.process_X(method='median')
# Out:
# 2025-05-12 16:09:18,013 - INFO - Traitement des outliers dans X en utilisant la méthode: median.
# 2025-05-12 16:09:18,014 - INFO - Recherche des outliers dans les colonnes numériques.
# 2025-05-12 16:09:18,461 - INFO - Outliers détectés dans les colonnes: ['Id', 'AvgTt', 'MedTt', 'ratio', 'AvgSp', 'HvgSp', 'MedSp', 'SdSp', 'Hits', 'P5sp', 'P10sp', 'P15sp', 'P20sp', 'P25sp', 'P30sp', 'P35sp', 'P40sp', 'P45sp', 'P50sp', 'P55sp', 'P60sp', 'P65sp', 'P70sp', 'P75sp', 'P80sp', 'P85sp', 'P90sp', 'P95sp', 'heure', 'zone']
# 2025-05-12 16:09:18,661 - INFO - Traitement des outliers terminé.

# %%
# Display the processed X
print(preprocessor.X.head())
# Out:
#    Id  AvgTt  MedTt  ratio  AvgSp  HvgSp  MedSp  SdSp   Hits  P5sp  ...  \
# 0   1   2.86   2.69   1.00   28.0   25.1   26.7   8.7  306.0  15.0  ...
# 1   1   2.78   2.64   0.97   27.7   25.8   27.2   7.2  738.0  18.0  ...
# 2   1   2.72   2.58   0.95   28.1   26.4   27.8   6.6  835.0  18.0  ...
# 3   1   2.73   2.59   0.95   28.1   26.3   27.7   6.7  811.0  18.0  ...
# 4   1   2.81   2.65   0.98   27.6   25.6   27.1   6.9  848.0  18.0  ...
#
#    P65sp  P70sp  P75sp  P80sp  P85sp  P90sp  P95sp  heure  capteur  zone
# 0   31.0   32.0   33.0   34.0   37.0   39.0   43.0      1      NaN   NaN
# 1   30.0   31.0   32.0   33.0   34.0   36.0   38.0     11      NaN   NaN
# 2   30.0   31.0   32.0   33.0   34.0   36.0   40.0     12      NaN   NaN
# 3   30.0   31.0   32.0   33.0   35.0   37.0   39.0     13      NaN   NaN
# 4   30.0   31.0   32.0   33.0   34.0   36.0   39.0     14      NaN   NaN
#
# [5 rows x 31 columns]

# %%
preprocessor.split_data(dfs_with_y[0])
# Out:
# 2025-05-12 16:09:40,797 - INFO - Division des données en ensembles d'entraînement et de test.
# 2025-05-12 16:09:40,841 - INFO - X_train shape: (2351, 31), X_test shape: (234199, 31)
# 2025-05-12 16:09:40,846 - INFO - y_train shape: (2351, 1), y_test shape: (234199, 1)
# X_train shape: (2351, 31)
# X_test shape: (234199, 31)
# y_train shape: (2351, 1)
# y_test shape: (234199, 1)
# X_train contient des NaN: False
# y_train contient des NaN: debit    False
# dtype: bool
# y_test contient des valeurs non NaN: debit    False
# dtype: bool
# (          Id  AvgTt  MedTt  ratio  AvgSp  HvgSp  MedSp  SdSp   Hits  P5sp  \
#  312       14   6.97   6.39   1.00   30.9   28.0   30.6   8.2  429.0  18.0
#  313       14   8.29   6.88   1.19   27.7   23.6   28.4   7.7  764.0  14.0
#  314       14   8.14   6.79   1.17   27.8   24.0   28.8   7.5  853.0  14.0
#  315       14   8.30   6.56   1.19   28.4   23.5   29.8   8.3  884.0  13.0
# ...
